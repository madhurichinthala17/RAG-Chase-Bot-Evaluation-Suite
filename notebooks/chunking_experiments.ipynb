# %% [markdown]
# ### Text Splitter used in Version v1 vs v2

# %% [markdown]
# ## Version 1

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=400)

# %% [markdown]
# ## Version 2

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1200, chunk_overlap=500)
